# %% [markdown]
# ### Project 1 - Demo
#
# This is a dummy demo iPython notebook, which may be used to give a live demo.
#
# - "Did you know that an iPython notebooks can be exported as pdf files?"
#     + "Yes, but only after being a huge pain in the ass"

# %%
from src.image_io import import_image
from src.plot import plot_multiple_arrays
# %matplotlib inline

# %%
im = import_image("resources/cat.png", as_array=True)

plot_multiple_arrays([[im]], "", ["Input Image"]);
